# %% [markdown]
#                                               Cookies
#
# In this exercise we are going to use brute force in order to solve for best cookie:
#
# ![cookies3.png](data:image/png;base64,...)
#
#
# Testing for different values until we get the flag:
#
# ![cookies4.png](data:image/png;base64,...)
#
# Finally with the value of 18:
#
# ![cookies.png](data:image/png;base64,...)

# %% [markdown]
#                                     Inspector
#
# We are presented with the following website.
#
# ![wbesite.png](data:image/png;base64,...)
#
# At first we are looking for the flag which is located in the HTML section of the website, through the source code we get:
#
# ![In1.png](data:image/png;base64,...)
#
#
# After this in the css file, through th style editor we get the second flag fragment as follows:
#
# ![In2.png](data:image/png;base64,...)
#
# And finally in the javascript file of the website we can find the last fragment of the flag which is:
#
# ![In3.png](data:image/png;base64,...)
#
# Resulting on:
#
# picoCTF{tru3_d3t3ct1ve_0r_ju5t_lucky?832b0699}

# %% [markdown]
#                                                   Scavanger Hunt
#
# We are presented with a different website for http://mercury.picoctf.net:55079/ where we are presented with:
#
# ![sc1.png](data:image/png;base64,...)
#
#
# As previously we did, first we are looking for the HMTL section:
#
#
# ![sc2.png](data:image/png;base64,...)
#
# Exploring the CSS File we get:
#
# ![sc3.png](data:image/png;base64,...)
#
#
# Now we write on the search bar of the page robots.txt Robots.txt controls the crawling and the overview of all existing URLs of your domain. There we find the third part of the flag.
#
# ![sc4.png](data:image/png;base64,...)
#
#
# As the next hints suggest, we enter on the search bar .htaccess, that is used to configure additional features for websites hosted on Apache web server. There we find the fourth part of the flag.
#
# ![sc5.png](data:image/png;base64,...)
#
# And finally we write .DS_Store. The DS_Store files are automatically generated every time the explorer comes into contact with a drive and are always hidden. There we find the last part of the flag
#
# ![sc6.png](data:image/png;base64,..._4_l0t_0f_pl4c3s_2_lo0k_74cceb07th4ts_4_l0t_0f_pl4c3s_2_lo0k_..._4_l0t_0f_pl4c3s_2_lo0k_...)
#
# Flag: {picoCTF{th4ts_4_l0t_0f_pl4c3s_2_lo0k_74cceb07}

# %% [markdown]
# [link text](https://)                                          Inspector
#
# W
#
# We are looking at first to the body of the respective html description in the source code of $https://jupiter.challenges.picoctf.org/problem/41511/$.
#
# ![In1.png](data:image/png;base64,...)
#
#
# Then with the help of the style editor we get the next fragment from css file:
#
# ![In2.png](data:image/png;base64,...)
#
# Finally, in the javascript file lies the last fragment:
#
# ![In3.png](data:image/png;base64,...
#
# Flag:picoCTF{tru3_d3t3ct1ve_0r_ju5t_lucky?832b0699}

# %% [markdown]
#                                                 Bookmarklet
#
# First we need to start running the instance. Then on the web page that is displayed we find a code.
# ![bok2.png](data:image/png;base64,...)
#
# We run this code in the browser console and the fing the flag.
#
# ![bok.png](data:image/png;base64,...)
#
# Flag:picoCTF{p@g3_turn3r_0148cb05}

# %% [markdown]
#                                           Web Decode
#
# The link from pico take us to the next web:
#
# ![web.png](data:image/png;base64,...)
#
# Next we look for the HTML section through the source code, we get:
#
# ![web1.png](data:image/png;base64,...)
#
# Finally, decoding with an open webpage![web2.png](data:image/png;base64,...):
#
# Flag:picoCTF{web_succ3ssfully_d3c0ded_07b91c79}

# %% [markdown]
#                               Dont-use-client-side
#
# Launching the website from the link in picoCTF we get:
#
# ![client1.png](data:image/png;base64,...)
#
# Then by source code we get:
#
# ![client2.png](data:image/png;base64,...)
#
# Then the flag is : picoCTF{no_clients_plz_1a3c89}

# %% [markdown]
#                                                 Logon
#
# We get the link to the web:
#
# ![logon.png](data:image/png;base64,...)
#
# As seen before trying for any particular credentials we get:
#
# ![logon2.png](data:image/png;base64,...)
#
# Now, considering that we have control over the cookies, given the conditions through inspector mode we can modify the value for admin from false to true;
#
#
# ![logon3.png](data:image/png;base64,...)
#
# At the moment of refreshing the webpage, this means the resend and aceptation of packets, the flag appears automatically as follows:
#
# ![logon4.png](data:image/png;base64,...)
#
# Flag:picoCTF{th3_c0nsp1r4cy_l1v3s_d1c24fef}

# %% [markdown]
#                             Who are You?
#
# The website is: http://mercury.picoctf.net:34588/
#
#
# ![who1.png](data:image/png;base64,...)
#
#
# In this exercise we are gonna use the idea of treating HTML Header as metada in order to get more information of the identity or identifiers involved in the conection.
